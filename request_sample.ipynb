# %%
import urllib.request
import json

# %%
zip_codes = json.load(open('zip_code_list.json', 'r', encoding='utf-8'))

# %%
fp = urllib.request.urlopen("https://api.promaptools.com/service/us/zip-lat-lng/get/?zip=95051&key=17o8dysaCDrgv1c")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

mystr
# Out:
# '{"status":1,"output":[{"zip":"95051","latitude":"37.350372","longitude":"-121.984750"}]}'

# %%
cdict = json.loads(mystr)
print(cdict)
print(cdict['output'][0]['latitude'], cdict['output'][0]['longitude'])
# Out:
# {'status': 1, 'output': [{'zip': '95051', 'latitude': '37.350372', 'longitude': '-121.984750'}]}
# 37.350372 -121.984750

# %%
fp = urllib.request.urlopen("https://www.melissa.com/v2/lookups/cityzip/city/?name=95050")
mybytes = fp.read()

mystr2 = mybytes.decode("utf8")
fp.close()

mystr2
# Out:
# '\r\n<!DOCTYPE html>\r\n<html lang="en-US">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\r\n    <meta name="robots" content="index, follow" />\r\n    \r\n    <meta name="keywords" content="city, town, places, zip code, postal" />\r\n    <meta name="description" content="Use this ZIP Codes by City lookup to find the ZIP codes within a city, along with additional data." />\r\n\r\n\r\n    <title>ZIP Codes by City Tool | Melissa Lookups</title>\r\n\r\n    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.3/css/bootstrap.min.css" integrity="sha384-MCw98/SFnGE8fJT3GXwEOngsV7Zt27NXFoaoApmYm81iuXoPkFOJwJ8ERdknLPMO" crossorigin="anonymous">\r\n    <link rel="stylesheet" href="/v2/lookups/css/sidebar.css">\r\n    <link rel="stylesheet" href="/v2/lookups/css/lookups-bs4.css?v=bdyE8ITANiFIO4M6Lw5Jp1yIkvkok0jc4P9a4FctXis">\r\n    <li
# ...

# %%
from lxml import etree

# %%
html = etree.HTML(mystr2)

# %%
text1 = html.xpath('//*[@id="tableOne"]/tbody/tr[1]/td[2]/a')

# %%
text1[0].text.strip()
# Out:
# 'SANTA CLARA'

# %%
text2 = html.xpath('//*[@id="tableOne"]/tbody/tr[1]/td[4]')

# %%
text2[0].text.strip()
# Out:
# 'CA'
