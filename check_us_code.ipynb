# %%
import pandas as pd
import json
from tqdm import tqdm
import pgeocode
from tzwhere import tzwhere

# %%
zip_code = json.load(open('data/zip_code_list.json', 'r'))

# %%
tz_dict ={
    'America/Adak': -10,
    'America/Anchorage': -9,
    'America/Asuncion': -4,
    'America/Boise': -7,
    'America/Chicago': -6,
    'America/Costa_Rica': -6,
    'America/Denver': -7,
    'America/Detroit': -5,
    'America/Guayaquil': -5,
    'America/Indiana/Indianapolis': -5,
    'America/Indiana/Knox': -6,
    'America/Indiana/Marengo': -5,
    'America/Indiana/Petersburg': -5,
    'America/Indiana/Tell_City': -6,
    'America/Indiana/Vevay': -5,
    'America/Indiana/Vincennes': -5,
    'America/Indiana/Winamac': -5,
    'America/Juneau': -9,
    'America/Kentucky/Louisville': -5,
    'America/Kentucky/Monticello': -5,
    'America/La_Paz': -4,
    'America/Lima': -5,
    'America/Los_Angeles': -8,
    'America/Managua': -6,
    'America/Menominee': -6,
    'America/New_York': -5,
    'America/Nome': -9,
    'America/North_Dakota/Beulah': -6,
    'America/North_Dakota/Center': -6,
    'America/North_Dakota/New_Salem': -6,
    'America/Ojinaga': -7,
    'America/Panama': -5,
    'America/Phoenix': -7,
    'America/Puerto_Rico': -4,
    'America/Santo_Domingo': -4,
    'America/Sitka': -9,
    'America/St_Thomas': -4,
    'America/Tegucigalpa': -6,
    'America/Toronto': -5,
    'America/Winnipeg': -6,
    'Asia/Hong_Kong': 8,
    'Asia/Karachi': 5,
    'Asia/Riyadh': 3,
    'Asia/Seoul': 9,
    'Asia/Singapore': 8,
    'Asia/Tokyo': 9,
    'Australia/Darwin': 9.5,
    'Australia/Melbourne': 10,
    'Australia/Sydney': 10,
    'Europe/Berlin': 1,
    'Europe/London': 0,
    'Pacific/Guam': 10,
    'Pacific/Honolulu': -10,
    'Pacific/Pago_Pago': -11,
    'Pacific/Saipan': 10,
    'America/Montreal': -5,
    None: False
}

# %%
ref_zip = pd.read_csv('data/uszips.csv')
ref_zip['zip'] = ref_zip['zip'].astype(str).str.zfill(5)

ref_dict = {}
for index, row in tqdm(ref_zip.iterrows()):
    cur_key = str(row['zip'])
    if cur_key in ref_dict:
        continue
    ref_dict[cur_key] = {}
    ref_dict[cur_key]['lat'] = row['lat']
    ref_dict[cur_key]['lng'] = row['lng']
    ref_dict[cur_key]['city'] = row['city']
    ref_dict[cur_key]['state'] = row['state_id']
    ref_dict[cur_key]['tz'] = row['timezone']
# Out:
# 33120it [00:02, 15775.15it/s]

# %%
ref_zip2 = pd.read_csv('data/US.txt', header=None, sep='\t')
tz = tzwhere.tzwhere()

for index, row in tqdm(ref_zip2.iterrows()):
    cur_key = str(row[1])
    if cur_key in ref_dict:
        continue
    ref_dict[cur_key] = {}
    ref_dict[cur_key]['lat'] = row[9]
    ref_dict[cur_key]['lng'] = row[10]
    ref_dict[cur_key]['city'] = row[2]
    ref_dict[cur_key]['state'] = row[4]
    ref_dict[cur_key]['tz'] = tz.tzNameAt(ref_dict[cur_key]['lat'], ref_dict[cur_key]['lng'])
# Out:
# 41483it [00:03, 12641.50it/s]

# %%
cleaned_zipcode = {}
cleaned_zipcode['nan'] = {
    'country': 0,
    'lat': False,
    'lng': False,
    'city': False,
    'state': False,
    'tz': False
}

for zc in tqdm(zip_code):
    zc = str(zc)
    if zc in cleaned_zipcode:
        continue
    
    if zc in ref_dict:
        nzc = zc
    elif '-' in zc and zc.split('-')[0] in ref_dict:
        nzc = zc.split('-')[0]
    elif len(zc) == 9 and zc[:5] in ref_dict:
        nzc = zc[:5]
    else:
        if '-' in zc:
            nzc = zc.split('-')[0]
        else:
            nzc = zc
        
        if nzc.isdigit():
            country = 2 + len(nzc)
        else:
            country = 2
        
        cleaned_zipcode[zc] = {
            'true_zip': nzc,
            'country': country,
            'lat': False,
            'lng': False,
            'city': False,
            'state': False,
            'tz': False
        }
        continue
    
    cleaned_zipcode[zc] = {
        'true_zip': nzc,
        'country': 1,
        'lat': ref_dict[nzc]['lat'],
        'lng': ref_dict[nzc]['lng'],
        'city': ref_dict[nzc]['city'],
        'state': ref_dict[nzc]['state'],
        'tz': tz_dict[ref_dict[nzc]['tz']]
    }
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 78535/78535 [00:00<00:00, 310266.75it/s]

# %%
cleaned_zipcode
# Out:
# {'nan': {'country': 0,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '32928': {'true_zip': '32928',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '07010-3107': {'true_zip': '07010',
#   'country': 1,
#   'lat': 40.82211,
#   'lng': -73.98794,
#   'city': 'Cliffside Park',
#   'state': 'NJ',
#   'tz': -5},
#  '91730-5743': {'true_zip': '91730',
#   'country': 1,
#   'lat': 34.09955,
#   'lng': -117.57847,
#   'city': 'Rancho Cucamonga',
#   'state': 'CA',
#   'tz': -8},
#  '65085': {'true_zip': '65085',
#   'country': 1,
#   'lat': 38.40179,
#   'lng': -92.07865,
#   'city': 'Westphalia',
#   'state': 'MO',
#   'tz': -6},
#  '95110': {'true_zip': '95110',
#   'country': 1,
#   'lat': 37.34662,
#   'lng': -121.90993,
#   'city': 'San Jose',
#   'state': 'CA',
#   'tz': -8},
#  '31503-0169': {'true_zip': '31503',
#   'country': 1,
#   'lat': 31.19789,
#   'lng': -82.41346,
#   'city': 'Waycross',
#   'state': 'GA',
#   'tz': -5},
#  '31044': {'true_zip': '31044',
#   'country': 1,
#   'lat': 32.63885,
#   'lng': -83.39336,
#   'city': 'Jeffersonville',
#   'state': 'GA',
#   'tz': -5},
#  '23435': {'true_zip': '23435',
#   'country': 1,
#   'lat': 36.83257,
#   'lng': -76.4829,
#   'city': 'Suffolk',
#   'state': 'VA',
#   'tz': -5},
#  '519070': {'true_zip': '519070',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '33156-7719': {'true_zip': '33156',
#   'country': 1,
#   'lat': 25.66828,
#   'lng': -80.29732,
#   'city': 'Miami',
#   'state': 'FL',
#   'tz': -5},
#  '981989034': {'true_zip': '98198',
#   'country': 1,
#   'lat': 47.3946,
#   'lng': -122.31122,
#   'city': 'Seattle',
#   'state': 'WA',
#   'tz': -8},
#  '75019-5656': {'true_zip': '75019',
#   'country': 1,
#   'lat': 32.96329,
#   'lng': -96.98553,
#   'city': 'Coppell',
#   'state': 'TX',
#   'tz': -6},
#  '93535-5810': {'true_zip': '93535',
#   'country': 1,
#   'lat': 34.71307,
#   'lng': -117.87823,
#   'city': 'Lancaster',
#   'state': 'CA',
#   'tz': -8},
#  '79541': {'true_zip': '79541',
#   'country': 1,
#   'lat': 32.15305,
#   'lng': -99.81497,
#   'city': 'Ovalo',
#   'state': 'TX',
#   'tz': -6},
#  '34039-0540': {'true_zip': '34039',
#   'country': 1,
#   'lat': -0.2299,
#   'lng': -78.525,
#   'city': 'APO AA',
#   'state': nan,
#   'tz': -5},
#  '20724': {'true_zip': '20724',
#   'country': 1,
#   'lat': 39.1011,
#   'lng': -76.80393,
#   'city': 'Laurel',
#   'state': 'MD',
#   'tz': -5},
#  '51011': {'true_zip': '51011',
#   'country': 1,
#   'lat': 42.91631,
#   'lng': -96.51445,
#   'city': 'Chatsworth',
#   'state': 'IA',
#   'tz': -6},
#  '49680-8624': {'true_zip': '49680',
#   'country': 1,
#   'lat': 44.64121,
#   'lng': -85.25244,
#   'city': 'South Boardman',
#   'state': 'MI',
#   'tz': -5},
#  '77566': {'true_zip': '77566',
#   'country': 1,
#   'lat': 29.05026,
#   'lng': -95.47542,
#   'city': 'Lake Jackson',
#   'state': 'TX',
#   'tz': -6},
#  '31202-0480': {'true_zip': '31202',
#   'country': 1,
#   'lat': 32.8407,
#   'lng': -83.6324,
#   'city': 'Macon',
#   'state': 'GA',
#   'tz': -5},
#  '85625-6134': {'true_zip': '85625',
#   'country': 1,
#   'lat': 31.8885,
#   'lng': -109.61185,
#   'city': 'Pearce',
#   'state': 'AZ',
#   'tz': -7},
#  '19810-2006': {'true_zip': '19810',
#   'country': 1,
#   'lat': 39.81865,
#   'lng': -75.50651,
#   'city': 'Wilmington',
#   'state': 'DE',
#   'tz': -5},
#  '04462': {'true_zip': '04462',
#   'country': 1,
#   'lat': 45.93691,
#   'lng': -68.98088,
#   'city': 'Millinocket',
#   'state': 'ME',
#   'tz': -5},
#  '63379': {'true_zip': '63379',
#   'country': 1,
#   'lat': 38.99816,
#   'lng': -90.9888,
#   'city': 'Troy',
#   'state': 'MO',
#   'tz': -6},
#  '70043': {'true_zip': '70043',
#   'country': 1,
#   'lat': 29.94804,
#   'lng': -89.96274,
#   'city': 'Chalmette',
#   'state': 'LA',
#   'tz': -6},
#  '97343': {'true_zip': '97343',
#   'country': 1,
#   'lat': 44.55856,
#   'lng': -123.7434,
#   'city': 'Eddyville',
#   'state': 'OR',
#   'tz': -8},
#  '50004': {'true_zip': '50004',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '92028-6513': {'true_zip': '92028',
#   'country': 1,
#   'lat': 33.38809,
#   'lng': -117.21247,
#   'city': 'Fallbrook',
#   'state': 'CA',
#   'tz': -8},
#  '47165': {'true_zip': '47165',
#   'country': 1,
#   'lat': 38.50454,
#   'lng': -86.00561,
#   'city': 'Pekin',
#   'state': 'IN',
#   'tz': -5},
#  '31753': {'true_zip': '31753',
#   'country': 1,
#   'lat': 31.2054,
#   'lng': -83.8776,
#   'city': 'Funston',
#   'state': 'GA',
#   'tz': -5},
#  '89523-9621': {'true_zip': '89523',
#   'country': 1,
#   'lat': 39.524,
#   'lng': -119.91376,
#   'city': 'Reno',
#   'state': 'NV',
#   'tz': -8},
#  '217713341': {'true_zip': '21771',
#   'country': 1,
#   'lat': 39.3935,
#   'lng': -77.15689,
#   'city': 'Mount Airy',
#   'state': 'MD',
#   'tz': -5},
#  '77065-2902': {'true_zip': '77065',
#   'country': 1,
#   'lat': 29.92696,
#   'lng': -95.60376,
#   'city': 'Houston',
#   'state': 'TX',
#   'tz': -6},
#  '33753': {'true_zip': '33753',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '48555': {'true_zip': '48555',
#   'country': 1,
#   'lat': 43.0113,
#   'lng': -83.7108,
#   'city': 'Flint',
#   'state': 'MI',
#   'tz': -5},
#  '98802': {'true_zip': '98802',
#   'country': 1,
#   'lat': 47.49059,
#   'lng': -120.16774,
#   'city': 'East Wenatchee',
#   'state': 'WA',
#   'tz': -8},
#  '53202-6711': {'true_zip': '53202',
#   'country': 1,
#   'lat': 43.04513,
#   'lng': -87.89819,
#   'city': 'Milwaukee',
#   'state': 'WI',
#   'tz': -6},
#  '55803': {'true_zip': '55803',
#   'country': 1,
#   'lat': 47.04751,
#   'lng': -92.05538,
#   'city': 'Duluth',
#   'state': 'MN',
#   'tz': -6},
#  '93203-1321': {'true_zip': '93203',
#   'country': 1,
#   'lat': 35.1119,
#   'lng': -118.83079,
#   'city': 'Arvin',
#   'state': 'CA',
#   'tz': -8},
#  '86305': {'true_zip': '86305',
#   'country': 1,
#   'lat': 34.81852,
#   'lng': -112.95842,
#   'city': 'Prescott',
#   'state': 'AZ',
#   'tz': -7},
#  '70521': {'true_zip': '70521',
#   'country': 1,
#   'lat': 30.3364,
#   'lng': -91.8492,
#   'city': 'Cecilia',
#   'state': 'LA',
#   'tz': -6},
#  '81626': {'true_zip': '81626',
#   'country': 1,
#   'lat': 40.5152,
#   'lng': -107.5465,
#   'city': 'Craig',
#   'state': 'CO',
#   'tz': -7},
#  '34285-5634': {'true_zip': '34285',
#   'country': 1,
#   'lat': 27.09153,
#   'lng': -82.43399,
#   'city': 'Venice',
#   'state': 'FL',
#   'tz': -5},
#  '55405': {'true_zip': '55405',
#   'country': 1,
#   'lat': 44.97026,
#   'lng': -93.30476,
#   'city': 'Minneapolis',
#   'state': 'MN',
#   'tz': -6},
#  '71120': {'true_zip': '71120',
#   'country': 1,
#   'lat': 32.6076,
#   'lng': -93.7526,
#   'city': 'Shreveport',
#   'state': 'LA',
#   'tz': -6},
#  '53029': {'true_zip': '53029',
#   'country': 1,
#   'lat': 43.14521,
#   'lng': -88.34689,
#   'city': 'Hartland',
#   'state': 'WI',
#   'tz': -6},
#  '286127246': {'true_zip': '28612',
#   'country': 1,
#   'lat': 35.66086,
#   'lng': -81.54008,
#   'city': 'Connelly Springs',
#   'state': 'NC',
#   'tz': -5},
#  '11204-3052': {'true_zip': '11204',
#   'country': 1,
#   'lat': 40.61871,
#   'lng': -73.98492,
#   'city': 'Brooklyn',
#   'state': 'NY',
#   'tz': -5},
#  '27865-9470': {'true_zip': '27865',
#   'country': 1,
#   'lat': 35.59315,
#   'lng': -76.81676,
#   'city': 'Pinetown',
#   'state': 'NC',
#   'tz': -5},
#  '62263': {'true_zip': '62263',
#   'country': 1,
#   'lat': 38.33016,
#   'lng': -89.40006,
#   'city': 'Nashville',
#   'state': 'IL',
#   'tz': -6},
#  '27970': {'true_zip': '27970',
#   'country': 1,
#   'lat': 35.87517,
#   'lng': -76.58169,
#   'city': 'Roper',
#   'state': 'NC',
#   'tz': -5},
#  '46033-9768': {'true_zip': '46033',
#   'country': 1,
#   'lat': 39.97888,
#   'lng': -86.08543,
#   'city': 'Carmel',
#   'state': 'IN',
#   'tz': -5},
#  '50147': {'true_zip': '50147',
#   'country': 1,
#   'lat': 40.62714,
#   'lng': -93.5491,
#   'city': 'Lineville',
#   'state': 'IA',
#   'tz': -6},
#  '685165229': {'true_zip': '68516',
#   'country': 1,
#   'lat': 40.73488,
#   'lng': -96.64258,
#   'city': 'Lincoln',
#   'state': 'NE',
#   'tz': -6},
#  '33073-2816': {'true_zip': '33073',
#   'country': 1,
#   'lat': 26.2985,
#   'lng': -80.1828,
#   'city': 'Pompano Beach',
#   'state': 'FL',
#   'tz': -5},
#  '08837-3609': {'true_zip': '08837',
#   'country': 1,
#   'lat': 40.51363,
#   'lng': -74.34465,
#   'city': 'Edison',
#   'state': 'NJ',
#   'tz': -5},
#  '34145': {'true_zip': '34145',
#   'country': 1,
#   'lat': 25.91903,
#   'lng': -81.6953,
#   'city': 'Marco Island',
#   'state': 'FL',
#   'tz': -5},
#  '33707-2156': {'true_zip': '33707',
#   'country': 1,
#   'lat': 27.75552,
#   'lng': -82.72564,
#   'city': 'Saint Petersburg',
#   'state': 'FL',
#   'tz': -5},
#  '18974-3208': {'true_zip': '18974',
#   'country': 1,
#   'lat': 40.21597,
#   'lng': -75.07296,
#   'city': 'Warminster',
#   'state': 'PA',
#   'tz': -5},
#  '85372': {'true_zip': '85372',
#   'country': 1,
#   'lat': 33.5975,
#   'lng': -112.2718,
#   'city': 'Sun City',
#   'state': 'AZ',
#   'tz': -7},
#  '77266': {'true_zip': '77266',
#   'country': 1,
#   'lat': 29.834,
#   'lng': -95.4342,
#   'city': 'Houston',
#   'state': 'TX',
#   'tz': -6},
#  '20182': {'true_zip': '20182',
#   'country': 1,
#   'lat': 38.7009,
#   'lng': -77.5857,
#   'city': 'Nokesville',
#   'state': 'VA',
#   'tz': -5},
#  '59074': {'true_zip': '59074',
#   'country': 1,
#   'lat': 46.36786,
#   'lng': -109.31631,
#   'city': 'Ryegate',
#   'state': 'MT',
#   'tz': -7},
#  '9382629': {'true_zip': '9382629',
#   'country': 9,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '62831': {'true_zip': '62831',
#   'country': 1,
#   'lat': 38.23068,
#   'lng': -89.22128,
#   'city': 'Du Bois',
#   'state': 'IL',
#   'tz': -6},
#  '330214441': {'true_zip': '33021',
#   'country': 1,
#   'lat': 26.02334,
#   'lng': -80.18758,
#   'city': 'Hollywood',
#   'state': 'FL',
#   'tz': -5},
#  '60613-3786': {'true_zip': '60613',
#   'country': 1,
#   'lat': 41.95586,
#   'lng': -87.65781,
#   'city': 'Chicago',
#   'state': 'IL',
#   'tz': -6},
#  '60499': {'true_zip': '60499',
#   'country': 1,
#   'lat': 41.8119,
#   'lng': -87.6873,
#   'city': 'Bedford Park',
#   'state': 'IL',
#   'tz': -6},
#  '85381-3598': {'true_zip': '85381',
#   'country': 1,
#   'lat': 33.60956,
#   'lng': -112.23168,
#   'city': 'Peoria',
#   'state': 'AZ',
#   'tz': -7},
#  '92083-1934': {'true_zip': '92083',
#   'country': 1,
#   'lat': 33.19787,
#   'lng': -117.24825,
#   'city': 'Vista',
#   'state': 'CA',
#   'tz': -8},
#  '79936-3644': {'true_zip': '79936',
#   'country': 1,
#   'lat': 31.77618,
#   'lng': -106.29786,
#   'city': 'El Paso',
#   'state': 'TX',
#   'tz': -7},
#  '20105-3049': {'true_zip': '20105',
#   'country': 1,
#   'lat': 38.96273,
#   'lng': -77.61002,
#   'city': 'Aldie',
#   'state': 'VA',
#   'tz': -5},
#  '56482': {'true_zip': '56482',
#   'country': 1,
#   'lat': 46.46532,
#   'lng': -95.14279,
#   'city': 'Wadena',
#   'state': 'MN',
#   'tz': -6},
#  '760445': {'true_zip': '760445',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '04626': {'true_zip': '04626',
#   'country': 1,
#   'lat': 44.68494,
#   'lng': -67.22169,
#   'city': 'Cutler',
#   'state': 'ME',
#   'tz': -5},
#  '448751504': {'true_zip': '44875',
#   'country': 1,
#   'lat': 40.88812,
#   'lng': -82.65272,
#   'city': 'Shelby',
#   'state': 'OH',
#   'tz': -5},
#  '60651-2312': {'true_zip': '60651',
#   'country': 1,
#   'lat': 41.90208,
#   'lng': -87.74089,
#   'city': 'Chicago',
#   'state': 'IL',
#   'tz': -6},
#  '72315': {'true_zip': '72315',
#   'country': 1,
#   'lat': 35.90486,
#   'lng': -89.90132,
#   'city': 'Blytheville',
#   'state': 'AR',
#   'tz': -6},
#  '341214': {'true_zip': '341214',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '14823': {'true_zip': '14823',
#   'country': 1,
#   'lat': 42.24857,
#   'lng': -77.55377,
#   'city': 'Canisteo',
#   'state': 'NY',
#   'tz': -5},
#  '54653': {'true_zip': '54653',
#   'country': 1,
#   'lat': 43.81746,
#   'lng': -90.90828,
#   'city': 'Rockland',
#   'state': 'WI',
#   'tz': -6},
#  '00977-0272': {'true_zip': '00977',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '77573-3039': {'true_zip': '77573',
#   'country': 1,
#   'lat': 29.50205,
#   'lng': -95.08652,
#   'city': 'League City',
#   'state': 'TX',
#   'tz': -6},
#  '53565': {'true_zip': '53565',
#   'country': 1,
#   'lat': 42.83912,
#   'lng': -90.16508,
#   'city': 'Mineral Point',
#   'state': 'WI',
#   'tz': -6},
#  '64465-9611': {'true_zip': '64465',
#   'country': 1,
#   'lat': 39.54904,
#   'lng': -94.29344,
#   'city': 'Lathrop',
#   'state': 'MO',
#   'tz': -6},
#  '95503': {'true_zip': '95503',
#   'country': 1,
#   'lat': 40.72426,
#   'lng': -124.09613,
#   'city': 'Eureka',
#   'state': 'CA',
#   'tz': -8},
#  '65052-1637': {'true_zip': '65052',
#   'country': 1,
#   'lat': 38.04943,
#   'lng': -92.65326,
#   'city': 'Linn Creek',
#   'state': 'MO',
#   'tz': -6},
#  '32222-0009': {'true_zip': '32222',
#   'country': 1,
#   'lat': 30.21682,
#   'lng': -81.82881,
#   'city': 'Jacksonville',
#   'state': 'FL',
#   'tz': -5},
#  '60607-1422': {'true_zip': '60607',
#   'country': 1,
#   'lat': 41.87503,
#   'lng': -87.65157,
#   'city': 'Chicago',
#   'state': 'IL',
#   'tz': -6},
#  '50469': {'true_zip': '50469',
#   'country': 1,
#   'lat': 42.99874,
#   'lng': -93.19417,
#   'city': 'Rockwell',
#   'state': 'IA',
#   'tz': -6},
#  '94546-6130': {'true_zip': '94546',
#   'country': 1,
#   'lat': 37.71498,
#   'lng': -122.08002,
#   'city': 'Castro Valley',
#   'state': 'CA',
#   'tz': -8},
#  '81422': {'true_zip': '81422',
#   'country': 1,
#   'lat': 38.34672,
#   'lng': -108.71155,
#   'city': 'Naturita',
#   'state': 'CO',
#   'tz': -7},
#  '103012415': {'true_zip': '10301',
#   'country': 1,
#   'lat': 40.62846,
#   'lng': -74.0962,
#   'city': 'Staten Island',
#   'state': 'NY',
#   'tz': -5},
#  '33563': {'true_zip': '33563',
#   'country': 1,
#   'lat': 28.01708,
#   'lng': -82.12457,
#   'city': 'Plant City',
#   'state': 'FL',
#   'tz': -5},
#  '94087-3537': {'true_zip': '94087',
#   'country': 1,
#   'lat': 37.35154,
#   'lng': -122.03688,
#   'city': 'Sunnyvale',
#   'state': 'CA',
#   'tz': -8},
#  '43981': {'true_zip': '43981',
#   'country': 1,
#   'lat': 40.1839,
#   'lng': -80.9959,
#   'city': 'New Athens',
#   'state': 'OH',
#   'tz': -5},
#  '59106': {'true_zip': '59106',
#   'country': 1,
#   'lat': 45.80792,
#   'lng': -108.6834,
#   'city': 'Billings',
#   'state': 'MT',
#   'tz': -7},
#  '19320-3226': {'true_zip': '19320',
#   'country': 1,
#   'lat': 39.96904,
#   'lng': -75.83098,
#   'city': 'Coatesville',
#   'state': 'PA',
#   'tz': -5},
#  '45066': {'true_zip': '45066',
#   'country': 1,
#   'lat': 39.54906,
#   'lng': -84.22313,
#   'city': 'Springboro',
#   'state': 'OH',
#   'tz': -5},
#  '47404-3808': {'true_zip': '47404',
#   'country': 1,
#   'lat': 39.21963,
#   'lng': -86.58968,
#   'city': 'Bloomington',
#   'state': 'IN',
#   'tz': -5},
#  '71973': {'true_zip': '71973',
#   'country': 1,
#   'lat': 34.29961,
#   'lng': -94.31719,
#   'city': 'Wickes',
#   'state': 'AR',
#   'tz': -6},
#  '50158-3336': {'true_zip': '50158',
#   'country': 1,
#   'lat': 42.05031,
#   'lng': -92.90058,
#   'city': 'Marshalltown',
#   'state': 'IA',
#   'tz': -6},
#  '05641-8038': {'true_zip': '05641',
#   'country': 1,
#   'lat': 44.18881,
#   'lng': -72.47294,
#   'city': 'Barre',
#   'state': 'VT',
#   'tz': -5},
#  '98391-0917': {'true_zip': '98391',
#   'country': 1,
#   'lat': 47.17717,
#   'lng': -122.17228,
#   'city': 'Bonney Lake',
#   'state': 'WA',
#   'tz': -8},
#  '95648-8633': {'true_zip': '95648',
#   'country': 1,
#   'lat': 38.9254,
#   'lng': -121.31167,
#   'city': 'Lincoln',
#   'state': 'CA',
#   'tz': -8},
#  '15101': {'true_zip': '15101',
#   'country': 1,
#   'lat': 40.58048,
#   'lng': -79.95446,
#   'city': 'Allison Park',
#   'state': 'PA',
#   'tz': -5},
#  '16415': {'true_zip': '16415',
#   'country': 1,
#   'lat': 42.0309,
#   'lng': -80.23041,
#   'city': 'Fairview',
#   'state': 'PA',
#   'tz': -5},
#  '68521-3159': {'true_zip': '68521',
#   'country': 1,
#   'lat': 40.86613,
#   'lng': -96.70947,
#   'city': 'Lincoln',
#   'state': 'NE',
#   'tz': -6},
#  '94403-3946': {'true_zip': '94403',
#   'country': 1,
#   'lat': 37.53847,
#   'lng': -122.30452,
#   'city': 'San Mateo',
#   'state': 'CA',
#   'tz': -8},
#  '33157-0900': {'true_zip': '33157',
#   'country': 1,
#   'lat': 25.60618,
#   'lng': -80.34258,
#   'city': 'Miami',
#   'state': 'FL',
#   'tz': -5},
#  '22801-6433': {'true_zip': '22801',
#   'country': 1,
#   'lat': 38.40459,
#   'lng': -78.87716,
#   'city': 'Harrisonburg',
#   'state': 'VA',
#   'tz': -5},
#  '92615-6126': {'true_zip': '92615',
#   'country': 1,
#   'lat': 33.6566,
#   'lng': -117.9699,
#   'city': 'Huntington Beach',
#   'state': 'CA',
#   'tz': -8},
#  '30078-1253': {'true_zip': '30078',
#   'country': 1,
#   'lat': 33.86166,
#   'lng': -84.01789,
#   'city': 'Snellville',
#   'state': 'GA',
#   'tz': -5},
#  '17607': {'true_zip': '17607',
#   'country': 1,
#   'lat': 40.0185,
#   'lng': -76.2976,
#   'city': 'Lancaster',
#   'state': 'PA',
#   'tz': -5},
#  '22980': {'true_zip': '22980',
#   'country': 1,
#   'lat': 38.09565,
#   'lng': -78.88513,
#   'city': 'Waynesboro',
#   'state': 'VA',
#   'tz': -5},
#  '30170-2321': {'true_zip': '30170',
#   'country': 1,
#   'lat': 33.42922,
#   'lng': -85.1695,
#   'city': 'Roopville',
#   'state': 'GA',
#   'tz': -5},
#  '01748-1593': {'true_zip': '01748',
#   'country': 1,
#   'lat': 42.2255,
#   'lng': -71.53779,
#   'city': 'Hopkinton',
#   'state': 'MA',
#   'tz': -5},
#  '20686': {'true_zip': '20686',
#   'country': 1,
#   'lat': 38.17905,
#   'lng': -76.43066,
#   'city': 'Saint Marys City',
#   'state': 'MD',
#   'tz': -5},
#  '13623': {'true_zip': '13623',
#   'country': 1,
#   'lat': 44.44976,
#   'lng': -75.75247,
#   'city': 'Chippewa Bay',
#   'state': 'NY',
#   'tz': -5},
#  '08629-1208': {'true_zip': '08629',
#   'country': 1,
#   'lat': 40.22064,
#   'lng': -74.73122,
#   'city': 'Trenton',
#   'state': 'NJ',
#   'tz': -5},
#  '39176': {'true_zip': '39176',
#   'country': 1,
#   'lat': 33.30197,
#   'lng': -89.76658,
#   'city': 'Vaiden',
#   'state': 'MS',
#   'tz': -6},
#  '18813': {'true_zip': '18813',
#   'country': 1,
#   'lat': 41.7512,
#   'lng': -75.8069,
#   'city': 'Brooklyn',
#   'state': 'PA',
#   'tz': -5},
#  '27220': {'true_zip': '27220',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '14550': {'true_zip': '14550',
#   'country': 1,
#   'lat': 42.67783,
#   'lng': -78.09104,
#   'city': 'Silver Springs',
#   'state': 'NY',
#   'tz': -5},
#  '78659': {'true_zip': '78659',
#   'country': 1,
#   'lat': 30.20888,
#   'lng': -97.12359,
#   'city': 'Paige',
#   'state': 'TX',
#   'tz': -6},
#  '54160': {'true_zip': '54160',
#   'country': 1,
#   'lat': 44.12057,
#   'lng': -88.10046,
#   'city': 'Potter',
#   'state': 'WI',
#   'tz': -6},
#  '80033': {'true_zip': '80033',
#   'country': 1,
#   'lat': 39.77309,
#   'lng': -105.1022,
#   'city': 'Wheat Ridge',
#   'state': 'CO',
#   'tz': -7},
#  '73143': {'true_zip': '73143',
#   'country': 1,
#   'lat': 35.5514,
#   'lng': -97.4075,
#   'city': 'Oklahoma City',
#   'state': 'OK',
#   'tz': -6},
#  '5822615': {'true_zip': '5822615',
#   'country': 9,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '62613': {'true_zip': '62613',
#   'country': 1,
#   'lat': 39.99177,
#   'lng': -89.66836,
#   'city': 'Athens',
#   'state': 'IL',
#   'tz': -6},
#  '33513': {'true_zip': '33513',
#   'country': 1,
#   'lat': 28.67022,
#   'lng': -82.16579,
#   'city': 'Bushnell',
#   'state': 'FL',
#   'tz': -5},
#  '04401-0424': {'true_zip': '04401',
#   'country': 1,
#   'lat': 44.84923,
#   'lng': -68.84479,
#   'city': 'Bangor',
#   'state': 'ME',
#   'tz': -5},
#  '5829109': {'true_zip': '5829109',
#   'country': 9,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '30344': {'true_zip': '30344',
#   'country': 1,
#   'lat': 33.67512,
#   'lng': -84.46026,
#   'city': 'Atlanta',
#   'state': 'GA',
#   'tz': -5},
#  '24277': {'true_zip': '24277',
#   'country': 1,
#   'lat': 36.74835,
#   'lng': -83.03076,
#   'city': 'Pennington Gap',
#   'state': 'VA',
#   'tz': -5},
#  '43062-5008': {'true_zip': '43062',
#   'country': 1,
#   'lat': 40.00752,
#   'lng': -82.68279,
#   'city': 'Pataskala',
#   'state': 'OH',
#   'tz': -5},
#  '63087': {'true_zip': '63087',
#   'country': 1,
#   'lat': 38.0131,
#   'lng': -90.45368,
#   'city': 'Valles Mines',
#   'state': 'MO',
#   'tz': -6},
#  '21043-6854': {'true_zip': '21043',
#   'country': 1,
#   'lat': 39.25753,
#   'lng': -76.7979,
#   'city': 'Ellicott City',
#   'state': 'MD',
#   'tz': -5},
#  '14422': {'true_zip': '14422',
#   'country': 1,
#   'lat': 43.08233,
#   'lng': -78.0657,
#   'city': 'Byron',
#   'state': 'NY',
#   'tz': -5},
#  '72122': {'true_zip': '72122',
#   'country': 1,
#   'lat': 34.78239,
#   'lng': -92.77737,
#   'city': 'Paron',
#   'state': 'AR',
#   'tz': -6},
#  '32937-3868': {'true_zip': '32937',
#   'country': 1,
#   'lat': 28.17832,
#   'lng': -80.60427,
#   'city': 'Satellite Beach',
#   'state': 'FL',
#   'tz': -5},
#  '49302-9749': {'true_zip': '49302',
#   'country': 1,
#   'lat': 42.82286,
#   'lng': -85.3986,
#   'city': 'Alto',
#   'state': 'MI',
#   'tz': -5},
#  '40379': {'true_zip': '40379',
#   'country': 1,
#   'lat': 38.31339,
#   'lng': -84.6872,
#   'city': 'Stamping Ground',
#   'state': 'KY',
#   'tz': -5},
#  '55121-2716': {'true_zip': '55121',
#   'country': 1,
#   'lat': 44.84706,
#   'lng': -93.15429,
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'tz': -6},
#  '90005-1802': {'true_zip': '90005',
#   'country': 1,
#   'lat': 34.05912,
#   'lng': -118.30654,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'tz': -8},
#  '85030': {'true_zip': '85030',
#   'country': 1,
#   'lat': 33.4484,
#   'lng': -112.074,
#   'city': 'Phoenix',
#   'state': 'AZ',
#   'tz': -7},
#  '66952': {'true_zip': '66952',
#   'country': 1,
#   'lat': 39.84109,
#   'lng': -98.60013,
#   'city': 'Lebanon',
#   'state': 'KS',
#   'tz': -6},
#  '56368': {'true_zip': '56368',
#   'country': 1,
#   'lat': 45.4521,
#   'lng': -94.53893,
#   'city': 'Richmond',
#   'state': 'MN',
#   'tz': -6},
#  '33145-2112': {'true_zip': '33145',
#   'country': 1,
#   'lat': 25.75309,
#   'lng': -80.23453,
#   'city': 'Miami',
#   'state': 'FL',
#   'tz': -5},
#  '98506-4544': {'true_zip': '98506',
#   'country': 1,
#   'lat': 47.10283,
#   'lng': -122.87324,
#   'city': 'Olympia',
#   'state': 'WA',
#   'tz': -8},
#  '24070': {'true_zip': '24070',
#   'country': 1,
#   'lat': 37.36705,
#   'lng': -80.20873,
#   'city': 'Catawba',
#   'state': 'VA',
#   'tz': -5},
#  '32839-3116': {'true_zip': '32839',
#   'country': 1,
#   'lat': 28.48834,
#   'lng': -81.4071,
#   'city': 'Orlando',
#   'state': 'FL',
#   'tz': -5},
#  '27582': {'true_zip': '27582',
#   'country': 1,
#   'lat': 36.46187,
#   'lng': -78.5743,
#   'city': 'Stovall',
#   'state': 'NC',
#   'tz': -5},
#  '75381': {'true_zip': '75381',
#   'country': 1,
#   'lat': 32.7673,
#   'lng': -96.7776,
#   'city': 'Dallas',
#   'state': 'TX',
#   'tz': -6},
#  '74401-6651': {'true_zip': '74401',
#   'country': 1,
#   'lat': 35.72181,
#   'lng': -95.46533,
#   'city': 'Muskogee',
#   'state': 'OK',
#   'tz': -6},
#  '91406-2315': {'true_zip': '91406',
#   'country': 1,
#   'lat': 34.19818,
#   'lng': -118.48975,
#   'city': 'Van Nuys',
#   'state': 'CA',
#   'tz': -8},
#  '92150-2174': {'true_zip': '92150',
#   'country': 1,
#   'lat': 32.7153,
#   'lng': -117.1573,
#   'city': 'San Diego',
#   'state': 'CA',
#   'tz': -8},
#  '20609': {'true_zip': '20609',
#   'country': 1,
#   'lat': 38.27423,
#   'lng': -76.75504,
#   'city': 'Avenue',
#   'state': 'MD',
#   'tz': -5},
#  '76226-0282': {'true_zip': '76226',
#   'country': 1,
#   'lat': 33.11035,
#   'lng': -97.16946,
#   'city': 'Argyle',
#   'state': 'TX',
#   'tz': -6},
#  '20152-6388': {'true_zip': '20152',
#   'country': 1,
#   'lat': 38.91757,
#   'lng': -77.50414,
#   'city': 'Chantilly',
#   'state': 'VA',
#   'tz': -5},
#  '92504-1743': {'true_zip': '92504',
#   'country': 1,
#   'lat': 33.90247,
#   'lng': -117.39662,
#   'city': 'Riverside',
#   'state': 'CA',
#   'tz': -8},
#  '75080-5200': {'true_zip': '75080',
#   'country': 1,
#   'lat': 32.97394,
#   'lng': -96.74202,
#   'city': 'Richardson',
#   'state': 'TX',
#   'tz': -6},
#  '57630': {'true_zip': '57630',
#   'country': 1,
#   'lat': 45.43917,
#   'lng': -100.90554,
#   'city': 'Glencross',
#   'state': 'SD',
#   'tz': -7},
#  '50119': {'true_zip': '50119',
#   'country': 1,
#   'lat': 41.31664,
#   'lng': -92.9475,
#   'city': 'Harvey',
#   'state': 'IA',
#   'tz': -6},
#  '92620-2189': {'true_zip': '92620',
#   'country': 1,
#   'lat': 33.7126,
#   'lng': -117.75069,
#   'city': 'Irvine',
#   'state': 'CA',
#   'tz': -8},
#  '49635-0455': {'true_zip': '49635',
#   'country': 1,
#   'lat': 44.61996,
#   'lng': -86.18479,
#   'city': 'Frankfort',
#   'state': 'MI',
#   'tz': -5},
#  '31316-5893': {'true_zip': '31316',
#   'country': 1,
#   'lat': 31.71717,
#   'lng': -81.72851,
#   'city': 'Ludowici',
#   'state': 'GA',
#   'tz': -5},
#  '60134-2734': {'true_zip': '60134',
#   'country': 1,
#   'lat': 41.87857,
#   'lng': -88.34194,
#   'city': 'Geneva',
#   'state': 'IL',
#   'tz': -6},
#  '24477-0646': {'true_zip': '24477',
#   'country': 1,
#   'lat': 38.00446,
#   'lng': -79.04232,
#   'city': 'Stuarts Draft',
#   'state': 'VA',
#   'tz': -5},
#  '4935435': {'true_zip': '4935435',
#   'country': 9,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '32533': {'true_zip': '32533',
#   'country': 1,
#   'lat': 30.61058,
#   'lng': -87.32678,
#   'city': 'Cantonment',
#   'state': 'FL',
#   'tz': -6},
#  '07039': {'true_zip': '07039',
#   'country': 1,
#   'lat': 40.7855,
#   'lng': -74.32908,
#   'city': 'Livingston',
#   'state': 'NJ',
#   'tz': -5},
#  '12848': {'true_zip': '12848',
#   'country': 1,
#   'lat': 43.1001,
#   'lng': -73.5246,
#   'city': 'Middle Falls',
#   'state': 'NY',
#   'tz': -5},
#  '518017': {'true_zip': '518017',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '44147-3274': {'true_zip': '44147',
#   'country': 1,
#   'lat': 41.31914,
#   'lng': -81.67871,
#   'city': 'Broadview Heights',
#   'state': 'OH',
#   'tz': -5},
#  '22703': {'true_zip': '22703',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '68771-7268': {'true_zip': '68771',
#   'country': 1,
#   'lat': 42.38321,
#   'lng': -97.35756,
#   'city': 'Randolph',
#   'state': 'NE',
#   'tz': -6},
#  '90017-2813': {'true_zip': '90017',
#   'country': 1,
#   'lat': 34.05291,
#   'lng': -118.2643,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'tz': -8},
#  '30305-2704': {'true_zip': '30305',
#   'country': 1,
#   'lat': 33.83564,
#   'lng': -84.38892,
#   'city': 'Atlanta',
#   'state': 'GA',
#   'tz': -5},
#  '95422-8276': {'true_zip': '95422',
#   'country': 1,
#   'lat': 38.97629,
#   'lng': -122.62312,
#   'city': 'Clearlake',
#   'state': 'CA',
#   'tz': -8},
#  '15489': {'true_zip': '15489',
#   'country': 1,
#   'lat': 39.96644,
#   'lng': -79.696,
#   'city': 'West Leisenring',
#   'state': 'PA',
#   'tz': -5},
#  '78347': {'true_zip': '78347',
#   'country': 1,
#   'lat': 27.5988,
#   'lng': -97.462,
#   'city': 'Chapman Ranch',
#   'state': 'TX',
#   'tz': -6},
#  '66061-8618': {'true_zip': '66061',
#   'country': 1,
#   'lat': 38.89668,
#   'lng': -94.87959,
#   'city': 'Olathe',
#   'state': 'KS',
#   'tz': -6},
#  '85031': {'true_zip': '85031',
#   'country': 1,
#   'lat': 33.49492,
#   'lng': -112.16833,
#   'city': 'Phoenix',
#   'state': 'AZ',
#   'tz': -7},
#  '76140-5750': {'true_zip': '76140',
#   'country': 1,
#   'lat': 32.6206,
#   'lng': -97.2701,
#   'city': 'Fort Worth',
#   'state': 'TX',
#   'tz': -6},
#  '83677': {'true_zip': '83677',
#   'country': 1,
#   'lat': 45.08023,
#   'lng': -115.53308,
#   'city': 'Yellow Pine',
#   'state': 'ID',
#   'tz': -7},
#  '52654': {'true_zip': '52654',
#   'country': 1,
#   'lat': 41.13751,
#   'lng': -91.66823,
#   'city': 'Wayland',
#   'state': 'IA',
#   'tz': -6},
#  '92648-2102': {'true_zip': '92648',
#   'country': 1,
#   'lat': 33.68244,
#   'lng': -118.01244,
#   'city': 'Huntington Beach',
#   'state': 'CA',
#   'tz': -8},
#  '19543-9488': {'true_zip': '19543',
#   'country': 1,
#   'lat': 40.17118,
#   'lng': -75.89241,
#   'city': 'Morgantown',
#   'state': 'PA',
#   'tz': -5},
#  '05346': {'true_zip': '05346',
#   'country': 1,
#   'lat': 43.02506,
#   'lng': -72.53167,
#   'city': 'Putney',
#   'state': 'VT',
#   'tz': -5},
#  '75160': {'true_zip': '75160',
#   'country': 1,
#   'lat': 32.76169,
#   'lng': -96.30017,
#   'city': 'Terrell',
#   'state': 'TX',
#   'tz': -6},
#  '60061-3107': {'true_zip': '60061',
#   'country': 1,
#   'lat': 42.23376,
#   'lng': -87.96074,
#   'city': 'Vernon Hills',
#   'state': 'IL',
#   'tz': -6},
#  '62058-1001': {'true_zip': '62058',
#   'country': 1,
#   'lat': 38.96895,
#   'lng': -89.76681,
#   'city': 'Livingston',
#   'state': 'IL',
#   'tz': -6},
#  '36276': {'true_zip': '36276',
#   'country': 1,
#   'lat': 33.13385,
#   'lng': -85.57061,
#   'city': 'Wadley',
#   'state': 'AL',
#   'tz': -6},
#  '80219-3401': {'true_zip': '80219',
#   'country': 1,
#   'lat': 39.69538,
#   'lng': -105.03438,
#   'city': 'Denver',
#   'state': 'CO',
#   'tz': -7},
#  '33917': {'true_zip': '33917',
#   'country': 1,
#   'lat': 26.73578,
#   'lng': -81.84351,
#   'city': 'North Fort Myers',
#   'state': 'FL',
#   'tz': -5},
#  '97078': {'true_zip': '97078',
#   'country': 1,
#   'lat': 45.452,
#   'lng': -122.7893,
#   'city': 'Beaverton',
#   'state': 'OR',
#   'tz': -8},
#  '34787-3139': {'true_zip': '34787',
#   'country': 1,
#   'lat': 28.48239,
#   'lng': -81.62774,
#   'city': 'Winter Garden',
#   'state': 'FL',
#   'tz': -5},
#  '92865': {'true_zip': '92865',
#   'country': 1,
#   'lat': 33.82887,
#   'lng': -117.84905,
#   'city': 'Orange',
#   'state': 'CA',
#   'tz': -8},
#  '54966': {'true_zip': '54966',
#   'country': 1,
#   'lat': 44.2122,
#   'lng': -89.50419,
#   'city': 'Plainfield',
#   'state': 'WI',
#   'tz': -6},
#  '63069-3122': {'true_zip': '63069',
#   'country': 1,
#   'lat': 38.48979,
#   'lng': -90.7304,
#   'city': 'Pacific',
#   'state': 'MO',
#   'tz': -6},
#  '35660': {'true_zip': '35660',
#   'country': 1,
#   'lat': 34.75596,
#   'lng': -87.70089,
#   'city': 'Sheffield',
#   'state': 'AL',
#   'tz': -6},
#  '60026-7715': {'true_zip': '60026',
#   'country': 1,
#   'lat': 42.09223,
#   'lng': -87.83745,
#   'city': 'Glenview',
#   'state': 'IL',
#   'tz': -6},
#  '31546': {'true_zip': '31546',
#   'country': 1,
#   'lat': 31.51199,
#   'lng': -81.80861,
#   'city': 'Jesup',
#   'state': 'GA',
#   'tz': -5},
#  '14487': {'true_zip': '14487',
#   'country': 1,
#   'lat': 42.81176,
#   'lng': -77.63595,
#   'city': 'Livonia',
#   'state': 'NY',
#   'tz': -5},
#  '85232': {'true_zip': '85232',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '90027-3972': {'true_zip': '90027',
#   'country': 1,
#   'lat': 34.12521,
#   'lng': -118.29057,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'tz': -8},
#  '53528-9442': {'true_zip': '53528',
#   'country': 1,
#   'lat': 43.11866,
#   'lng': -89.63877,
#   'city': 'Cross Plains',
#   'state': 'WI',
#   'tz': -6},
#  '78720': {'true_zip': '78720',
#   'country': 1,
#   'lat': 30.3264,
#   'lng': -97.7713,
#   'city': 'Austin',
#   'state': 'TX',
#   'tz': -6},
#  '305193019': {'true_zip': '30519',
#   'country': 1,
#   'lat': 34.08798,
#   'lng': -83.94118,
#   'city': 'Buford',
#   'state': 'GA',
#   'tz': -5},
#  '97303': {'true_zip': '97303',
#   'country': 1,
#   'lat': 45.03045,
#   'lng': -123.02438,
#   'city': 'Salem',
#   'state': 'OR',
#   'tz': -8},
#  '33483': {'true_zip': '33483',
#   'country': 1,
#   'lat': 26.46118,
#   'lng': -80.06378,
#   'city': 'Delray Beach',
#   'state': 'FL',
#   'tz': -5},
#  '05734': {'true_zip': '05734',
#   'country': 1,
#   'lat': 43.9821,
#   'lng': -73.33027,
#   'city': 'Bridport',
#   'state': 'VT',
#   'tz': -5},
#  '30531': {'true_zip': '30531',
#   'country': 1,
#   'lat': 34.51014,
#   'lng': -83.59159,
#   'city': 'Cornelia',
#   'state': 'GA',
#   'tz': -5},
#  '32164-7171': {'true_zip': '32164',
#   'country': 1,
#   'lat': 29.48409,
#   'lng': -81.21789,
#   'city': 'Palm Coast',
#   'state': 'FL',
#   'tz': -5},
#  '05148': {'true_zip': '05148',
#   'country': 1,
#   'lat': 43.22877,
#   'lng': -72.79999,
#   'city': 'Londonderry',
#   'state': 'VT',
#   'tz': -5},
#  '11729-5742': {'true_zip': '11729',
#   'country': 1,
#   'lat': 40.76279,
#   'lng': -73.32177,
#   'city': 'Deer Park',
#   'state': 'NY',
#   'tz': -5},
#  '30035-4307': {'true_zip': '30035',
#   'country': 1,
#   'lat': 33.72556,
#   'lng': -84.20523,
#   'city': 'Decatur',
#   'state': 'GA',
#   'tz': -5},
#  '11358-1134': {'true_zip': '11358',
#   'country': 1,
#   'lat': 40.76044,
#   'lng': -73.79632,
#   'city': 'Flushing',
#   'state': 'NY',
#   'tz': -5},
#  '04493': {'true_zip': '04493',
#   'country': 1,
#   'lat': 45.23786,
#   'lng': -68.5338,
#   'city': 'West Enfield',
#   'state': 'ME',
#   'tz': -5},
#  '25413': {'true_zip': '25413',
#   'country': 1,
#   'lat': 39.31619,
#   'lng': -78.05298,
#   'city': 'Bunker Hill',
#   'state': 'WV',
#   'tz': -5},
#  '55786': {'true_zip': '55786',
#   'country': 1,
#   'lat': 47.31638,
#   'lng': -93.39046,
#   'city': 'Taconite',
#   'state': 'MN',
#   'tz': -6},
#  '10468-3269': {'true_zip': '10468',
#   'country': 1,
#   'lat': 40.86804,
#   'lng': -73.90006,
#   'city': 'Bronx',
#   'state': 'NY',
#   'tz': -5},
#  '34236': {'true_zip': '34236',
#   'country': 1,
#   'lat': 27.32626,
#   'lng': -82.5572,
#   'city': 'Sarasota',
#   'state': 'FL',
#   'tz': -5},
#  '981362815': {'true_zip': '98136',
#   'country': 1,
#   'lat': 47.53676,
#   'lng': -122.38986,
#   'city': 'Seattle',
#   'state': 'WA',
#   'tz': -8},
#  '070221514': {'true_zip': '07022',
#   'country': 1,
#   'lat': 40.81818,
#   'lng': -74.00221,
#   'city': 'Fairview',
#   'state': 'NJ',
#   'tz': -5},
#  '48160': {'true_zip': '48160',
#   'country': 1,
#   'lat': 42.08085,
#   'lng': -83.67886,
#   'city': 'Milan',
#   'state': 'MI',
#   'tz': -5},
#  '89112': {'true_zip': '89112',
#   'country': 1,
#   'lat': 36.1578,
#   'lng': -115.0256,
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'tz': -8},
#  '33914': {'true_zip': '33914',
#   'country': 1,
#   'lat': 26.56798,
#   'lng': -82.01549,
#   'city': 'Cape Coral',
#   'state': 'FL',
#   'tz': -5},
#  '02244': {'true_zip': '02244',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '96080-7812': {'true_zip': '96080',
#   'country': 1,
#   'lat': 40.16515,
#   'lng': -122.38167,
#   'city': 'Red Bluff',
#   'state': 'CA',
#   'tz': -8},
#  '62959': {'true_zip': '62959',
#   'country': 1,
#   'lat': 37.71804,
#   'lng': -88.90775,
#   'city': 'Marion',
#   'state': 'IL',
#   'tz': -6},
#  '01038': {'true_zip': '01038',
#   'country': 1,
#   'lat': 42.38548,
#   'lng': -72.60701,
#   'city': 'Hatfield',
#   'state': 'MA',
#   'tz': -5},
#  '77469-5707': {'true_zip': '77469',
#   'country': 1,
#   'lat': 29.48,
#   'lng': -95.68313,
#   'city': 'Richmond',
#   'state': 'TX',
#   'tz': -6},
#  '329200242': {'true_zip': '32920',
#   'country': 1,
#   'lat': 28.39497,
#   'lng': -80.62083,
#   'city': 'Cape Canaveral',
#   'state': 'FL',
#   'tz': -5},
#  '39046': {'true_zip': '39046',
#   'country': 1,
#   'lat': 32.63195,
#   'lng': -89.98542,
#   'city': 'Canton',
#   'state': 'MS',
#   'tz': -6},
#  '510410': {'true_zip': '510410',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '56145': {'true_zip': '56145',
#   'country': 1,
#   'lat': 44.05473,
#   'lng': -95.17571,
#   'city': 'Jeffers',
#   'state': 'MN',
#   'tz': -6},
#  '85719': {'true_zip': '85719',
#   'country': 1,
#   'lat': 32.24671,
#   'lng': -110.9487,
#   'city': 'Tucson',
#   'state': 'AZ',
#   'tz': -7},
#  '30096': {'true_zip': '30096',
#   'country': 1,
#   'lat': 33.97681,
#   'lng': -84.14824,
#   'city': 'Duluth',
#   'state': 'GA',
#   'tz': -5},
#  '85717': {'true_zip': '85717',
#   'country': 1,
#   'lat': 32.2217,
#   'lng': -110.9265,
#   'city': 'Tucson',
#   'state': 'AZ',
#   'tz': -7},
#  '26801': {'true_zip': '26801',
#   'country': 1,
#   'lat': 39.05028,
#   'lng': -78.80364,
#   'city': 'Baker',
#   'state': 'WV',
#   'tz': -5},
#  '90618': {'true_zip': '90618',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '65730': {'true_zip': '65730',
#   'country': 1,
#   'lat': 36.62367,
#   'lng': -94.17715,
#   'city': 'Powell',
#   'state': 'MO',
#   'tz': -6},
#  '44102-2362': {'true_zip': '44102',
#   'country': 1,
#   'lat': 41.47524,
#   'lng': -81.73766,
#   'city': 'Cleveland',
#   'state': 'OH',
#   'tz': -5},
#  '3050821': {'true_zip': '3050821',
#   'country': 9,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '23323-3903': {'true_zip': '23323',
#   'country': 1,
#   'lat': 36.67487,
#   'lng': -76.39162,
#   'city': 'Chesapeake',
#   'state': 'VA',
#   'tz': -5},
#  '34974-1540': {'true_zip': '34974',
#   'country': 1,
#   'lat': 27.14475,
#   'lng': -80.94548,
#   'city': 'Okeechobee',
#   'state': 'FL',
#   'tz': -5},
#  '32437': {'true_zip': '32437',
#   'country': 1,
#   'lat': 30.43364,
#   'lng': -85.90551,
#   'city': 'Ebro',
#   'state': 'FL',
#   'tz': -6},
#  '80265': {'true_zip': '80265',
#   'country': 1,
#   'lat': 39.7392,
#   'lng': -104.9847,
#   'city': 'Denver',
#   'state': 'CO',
#   'tz': -7},
#  '92008-4244': {'true_zip': '92008',
#   'country': 1,
#   'lat': 33.14594,
#   'lng': -117.31785,
#   'city': 'Carlsbad',
#   'state': 'CA',
#   'tz': -8},
#  '78624-1535': {'true_zip': '78624',
#   'country': 1,
#   'lat': 30.28151,
#   'lng': -98.87712,
#   'city': 'Fredericksburg',
#   'state': 'TX',
#   'tz': -6},
#  '62553': {'true_zip': '62553',
#   'country': 1,
#   'lat': 39.26621,
#   'lng': -89.10717,
#   'city': 'Oconee',
#   'state': 'IL',
#   'tz': -6},
#  '90746': {'true_zip': '90746',
#   'country': 1,
#   'lat': 33.85888,
#   'lng': -118.25526,
#   'city': 'Carson',
#   'state': 'CA',
#   'tz': -8},
#  '77057-6244': {'true_zip': '77057',
#   'country': 1,
#   'lat': 29.74546,
#   'lng': -95.48868,
#   'city': 'Houston',
#   'state': 'TX',
#   'tz': -6},
#  '18801': {'true_zip': '18801',
#   'country': 1,
#   'lat': 41.82978,
#   'lng': -75.93836,
#   'city': 'Montrose',
#   'state': 'PA',
#   'tz': -5},
#  '55107-0263': {'true_zip': '55107',
#   'country': 1,
#   'lat': 44.93108,
#   'lng': -93.07958,
#   'city': 'Saint Paul',
#   'state': 'MN',
#   'tz': -6},
#  '30449': {'true_zip': '30449',
#   'country': 1,
#   'lat': 32.52987,
#   'lng': -81.55148,
#   'city': 'Oliver',
#   'state': 'GA',
#   'tz': -5},
#  '85120': {'true_zip': '85120',
#   'country': 1,
#   'lat': 33.40301,
#   'lng': -111.56787,
#   'city': 'Apache Junction',
#   'state': 'AZ',
#   'tz': -7},
#  '41616': {'true_zip': '41616',
#   'country': 1,
#   'lat': 37.58107,
#   'lng': -82.8767,
#   'city': 'David',
#   'state': 'KY',
#   'tz': -5},
#  '63967': {'true_zip': '63967',
#   'country': 1,
#   'lat': 36.94607,
#   'lng': -90.47916,
#   'city': 'Williamsville',
#   'state': 'MO',
#   'tz': -6},
#  '91351-5017': {'true_zip': '91351',
#   'country': 1,
#   'lat': 34.43321,
#   'lng': -118.46295,
#   'city': 'Canyon Country',
#   'state': 'CA',
#   'tz': -8},
#  '07446-1220': {'true_zip': '07446',
#   'country': 1,
#   'lat': 41.05944,
#   'lng': -74.14545,
#   'city': 'Ramsey',
#   'state': 'NJ',
#   'tz': -5},
#  '16749': {'true_zip': '16749',
#   'country': 1,
#   'lat': 41.76542,
#   'lng': -78.4365,
#   'city': 'Smethport',
#   'state': 'PA',
#   'tz': -5},
#  '112045344': {'true_zip': '11204',
#   'country': 1,
#   'lat': 40.61871,
#   'lng': -73.98492,
#   'city': 'Brooklyn',
#   'state': 'NY',
#   'tz': -5},
#  '62952': {'true_zip': '62952',
#   'country': 1,
#   'lat': 37.41823,
#   'lng': -89.33724,
#   'city': 'Jonesboro',
#   'state': 'IL',
#   'tz': -6},
#  '97062-9486': {'true_zip': '97062',
#   'country': 1,
#   'lat': 45.36875,
#   'lng': -122.76196,
#   'city': 'Tualatin',
#   'state': 'OR',
#   'tz': -8},
#  '06331': {'true_zip': '06331',
#   'country': 1,
#   'lat': 41.69792,
#   'lng': -71.99975,
#   'city': 'Canterbury',
#   'state': 'CT',
#   'tz': -5},
#  '60632-1535': {'true_zip': '60632',
#   'country': 1,
#   'lat': 41.81133,
#   'lng': -87.71335,
#   'city': 'Chicago',
#   'state': 'IL',
#   'tz': -6},
#  '80130-7171': {'true_zip': '80130',
#   'country': 1,
#   'lat': 39.53062,
#   'lng': -104.92323,
#   'city': 'Littleton',
#   'state': 'CO',
#   'tz': -7},
#  '25262': {'true_zip': '25262',
#   'country': 1,
#   'lat': 38.90658,
#   'lng': -81.82867,
#   'city': 'Millwood',
#   'state': 'WV',
#   'tz': -5},
#  '46176-3292': {'true_zip': '46176',
#   'country': 1,
#   'lat': 39.52751,
#   'lng': -85.77396,
#   'city': 'Shelbyville',
#   'state': 'IN',
#   'tz': -5},
#  '52577': {'true_zip': '52577',
#   'country': 1,
#   'lat': 41.27193,
#   'lng': -92.66047,
#   'city': 'Oskaloosa',
#   'state': 'IA',
#   'tz': -6},
#  '66049-2743': {'true_zip': '66049',
#   'country': 1,
#   'lat': 38.9824,
#   'lng': -95.34464,
#   'city': 'Lawrence',
#   'state': 'KS',
#   'tz': -6},
#  '21117-6007': {'true_zip': '21117',
#   'country': 1,
#   'lat': 39.4271,
#   'lng': -76.77713,
#   'city': 'Owings Mills',
#   'state': 'MD',
#   'tz': -5},
#  '16037-0042': {'true_zip': '16037',
#   'country': 1,
#   'lat': 40.85315,
#   'lng': -80.12822,
#   'city': 'Harmony',
#   'state': 'PA',
#   'tz': -5},
#  '77532-1540': {'true_zip': '77532',
#   'country': 1,
#   'lat': 29.93018,
#   'lng': -95.05654,
#   'city': 'Crosby',
#   'state': 'TX',
#   'tz': -6},
#  '21216': {'true_zip': '21216',
#   'country': 1,
#   'lat': 39.31104,
#   'lng': -76.67206,
#   'city': 'Baltimore',
#   'state': 'MD',
#   'tz': -5},
#  '49599': {'true_zip': '49599',
#   'country': 1,
#   'lat': 43.0314,
#   'lng': -85.5503,
#   'city': 'Grand Rapids',
#   'state': 'MI',
#   'tz': -5},
#  '33890': {'true_zip': '33890',
#   'country': 1,
#   'lat': 27.44704,
#   'lng': -81.6889,
#   'city': 'Zolfo Springs',
#   'state': 'FL',
#   'tz': -5},
#  '92602-6055': {'true_zip': '92602',
#   'country': 1,
#   'lat': 33.74582,
#   'lng': -117.74867,
#   'city': 'Irvine',
#   'state': 'CA',
#   'tz': -8},
#  '11101-3300': {'true_zip': '11101',
#   'country': 1,
#   'lat': 40.74671,
#   'lng': -73.93893,
#   'city': 'Long Island City',
#   'state': 'NY',
#   'tz': -5},
#  '32601-2854': {'true_zip': '32601',
#   'country': 1,
#   'lat': 29.64888,
#   'lng': -82.32498,
#   'city': 'Gainesville',
#   'state': 'FL',
#   'tz': -5},
#  '73159-5109': {'true_zip': '73159',
#   'country': 1,
#   'lat': 35.39008,
#   'lng': -97.57679,
#   'city': 'Oklahoma City',
#   'state': 'OK',
#   'tz': -6},
#  '11709-3203': {'true_zip': '11709',
#   'country': 1,
#   'lat': 40.90688,
#   'lng': -73.5597,
#   'city': 'Bayville',
#   'state': 'NY',
#   'tz': -5},
#  '38627': {'true_zip': '38627',
#   'country': 1,
#   'lat': 34.42428,
#   'lng': -89.2237,
#   'city': 'Etta',
#   'state': 'MS',
#   'tz': -6},
#  '47303': {'true_zip': '47303',
#   'country': 1,
#   'lat': 40.27154,
#   'lng': -85.37801,
#   'city': 'Muncie',
#   'state': 'IN',
#   'tz': -5},
#  '10045': {'true_zip': '10045',
#   'country': 1,
#   'lat': 40.7086,
#   'lng': -74.0087,
#   'city': 'New York',
#   'state': 'NY',
#   'tz': -5},
#  '70650': {'true_zip': '70650',
#   'country': 1,
#   'lat': 30.23744,
#   'lng': -92.9232,
#   'city': 'Lacassine',
#   'state': 'LA',
#   'tz': -6},
#  '73069': {'true_zip': '73069',
#   'country': 1,
#   'lat': 35.24963,
#   'lng': -97.46292,
#   'city': 'Norman',
#   'state': 'OK',
#   'tz': -6},
#  '27283-8307': {'true_zip': '27283',
#   'country': 1,
#   'lat': 35.95195,
#   'lng': -79.63724,
#   'city': 'Julian',
#   'state': 'NC',
#   'tz': -5},
#  '92117-6857': {'true_zip': '92117',
#   'country': 1,
#   'lat': 32.82461,
#   'lng': -117.19954,
#   'city': 'San Diego',
#   'state': 'CA',
#   'tz': -8},
#  '73664': {'true_zip': '73664',
#   'country': 1,
#   'lat': 35.1859,
#   'lng': -99.24866,
#   'city': 'Sentinel',
#   'state': 'OK',
#   'tz': -6},
#  '77225': {'true_zip': '77225',
#   'country': 1,
#   'lat': 29.834,
#   'lng': -95.4342,
#   'city': 'Houston',
#   'state': 'TX',
#   'tz': -6},
#  '20001-3743': {'true_zip': '20001',
#   'country': 1,
#   'lat': 38.91085,
#   'lng': -77.0179,
#   'city': 'Washington',
#   'state': 'DC',
#   'tz': -5},
#  '85282-2826': {'true_zip': '85282',
#   'country': 1,
#   'lat': 33.39414,
#   'lng': -111.93184,
#   'city': 'Tempe',
#   'state': 'AZ',
#   'tz': -7},
#  '12901-3489': {'true_zip': '12901',
#   'country': 1,
#   'lat': 44.70382,
#   'lng': -73.47382,
#   'city': 'Plattsburgh',
#   'state': 'NY',
#   'tz': -5},
#  '73442': {'true_zip': '73442',
#   'country': 1,
#   'lat': 34.3265,
#   'lng': -97.6718,
#   'city': 'Loco',
#   'state': 'OK',
#   'tz': -6},
#  '92887-3330': {'true_zip': '92887',
#   'country': 1,
#   'lat': 33.88471,
#   'lng': -117.73124,
#   'city': 'Yorba Linda',
#   'state': 'CA',
#   'tz': -8},
#  '07601-5501': {'true_zip': '07601',
#   'country': 1,
#   'lat': 40.889,
#   'lng': -74.0461,
#   'city': 'Hackensack',
#   'state': 'NJ',
#   'tz': -5},
#  '76904': {'true_zip': '76904',
#   'country': 1,
#   'lat': 31.2836,
#   'lng': -100.39452,
#   'city': 'San Angelo',
#   'state': 'TX',
#   'tz': -6},
#  '18625': {'true_zip': '18625',
#   'country': 1,
#   'lat': 41.50959,
#   'lng': -75.85078,
#   'city': 'Lake Winola',
#   'state': 'PA',
#   'tz': -5},
#  '26836': {'true_zip': '26836',
#   'country': 1,
#   'lat': 38.99078,
#   'lng': -78.97451,
#   'city': 'Moorefield',
#   'state': 'WV',
#   'tz': -5},
#  '98270-4058': {'true_zip': '98270',
#   'country': 1,
#   'lat': 48.0596,
#   'lng': -122.14454,
#   'city': 'Marysville',
#   'state': 'WA',
#   'tz': -8},
#  '60201-1812': {'true_zip': '60201',
#   'country': 1,
#   'lat': 42.05652,
#   'lng': -87.6972,
#   'city': 'Evanston',
#   'state': 'IL',
#   'tz': -6},
#  '98609': {'true_zip': '98609',
#   'country': 1,
#   'lat': 46.0715,
#   'lng': -122.8648,
#   'city': 'Carrolls',
#   'state': 'WA',
#   'tz': -8},
#  '45305': {'true_zip': '45305',
#   'country': 1,
#   'lat': 39.63474,
#   'lng': -84.07969,
#   'city': 'Bellbrook',
#   'state': 'OH',
#   'tz': -5},
#  '20781-1533': {'true_zip': '20781',
#   'country': 1,
#   'lat': 38.9432,
#   'lng': -76.93649,
#   'city': 'Hyattsville',
#   'state': 'MD',
#   'tz': -5},
#  '10036': {'true_zip': '10036',
#   'country': 1,
#   'lat': 40.75927,
#   'lng': -73.98999,
#   'city': 'New York',
#   'state': 'NY',
#   'tz': -5},
#  '64119-1516': {'true_zip': '64119',
#   'country': 1,
#   'lat': 39.20938,
#   'lng': -94.51934,
#   'city': 'Kansas City',
#   'state': 'MO',
#   'tz': -6},
#  '40205-2671': {'true_zip': '40205',
#   'country': 1,
#   'lat': 38.22345,
#   'lng': -85.68262,
#   'city': 'Louisville',
#   'state': 'KY',
#   'tz': -5},
#  '93030-8010': {'true_zip': '93030',
#   'country': 1,
#   'lat': 34.2053,
#   'lng': -119.17482,
#   'city': 'Oxnard',
#   'state': 'CA',
#   'tz': -8},
#  '472658388': {'true_zip': '47265',
#   'country': 1,
#   'lat': 39.01233,
#   'lng': -85.62763,
#   'city': 'North Vernon',
#   'state': 'IN',
#   'tz': -5},
#  '61791': {'true_zip': '61791',
#   'country': 1,
#   'lat': 40.5192,
#   'lng': -88.8643,
#   'city': 'Bloomington',
#   'state': 'IL',
#   'tz': -6},
#  '61482': {'true_zip': '61482',
#   'country': 1,
#   'lat': 40.38838,
#   'lng': -90.41175,
#   'city': 'Table Grove',
#   'state': 'IL',
#   'tz': -6},
#  '17949': {'true_zip': '17949',
#   'country': 1,
#   'lat': 40.79397,
#   'lng': -76.24226,
#   'city': 'Mahanoy Plane',
#   'state': 'PA',
#   'tz': -5},
#  '11366': {'true_zip': '11366',
#   'country': 1,
#   'lat': 40.72817,
#   'lng': -73.78491,
#   'city': 'Fresh Meadows',
#   'state': 'NY',
#   'tz': -5},
#  '32301': {'true_zip': '32301',
#   'country': 1,
#   'lat': 30.42563,
#   'lng': -84.25823,
#   'city': 'Tallahassee',
#   'state': 'FL',
#   'tz': -5},
#  '91741-3251': {'true_zip': '91741',
#   'country': 1,
#   'lat': 34.15372,
#   'lng': -117.84368,
#   'city': 'Glendora',
#   'state': 'CA',
#   'tz': -8},
#  '43144': {'true_zip': '43144',
#   'country': 1,
#   'lat': 39.52851,
#   'lng': -82.19212,
#   'city': 'Murray City',
#   'state': 'OH',
#   'tz': -5},
#  '32301-4717': {'true_zip': '32301',
#   'country': 1,
#   'lat': 30.42563,
#   'lng': -84.25823,
#   'city': 'Tallahassee',
#   'state': 'FL',
#   'tz': -5},
#  '95695-3558': {'true_zip': '95695',
#   'country': 1,
#   'lat': 38.6871,
#   'lng': -121.85704,
#   'city': 'Woodland',
#   'state': 'CA',
#   'tz': -8},
#  '77491': {'true_zip': '77491',
#   'country': 1,
#   'lat': 29.7858,
#   'lng': -95.8244,
#   'city': 'Katy',
#   'state': 'TX',
#   'tz': -6},
#  '06770-3816': {'true_zip': '06770',
#   'country': 1,
#   'lat': 41.48923,
#   'lng': -73.053,
#   'city': 'Naugatuck',
#   'state': 'CT',
#   'tz': -5},
#  '00924': {'true_zip': '00924',
#   'country': 1,
#   'lat': 18.39826,
#   'lng': -66.01288,
#   'city': 'San Juan',
#   'state': 'PR',
#   'tz': -4},
#  '80234-3950': {'true_zip': '80234',
#   'country': 1,
#   'lat': 39.91226,
#   'lng': -105.00553,
#   'city': 'Denver',
#   'state': 'CO',
#   'tz': -7},
#  '22443-1800': {'true_zip': '22443',
#   'country': 1,
#   'lat': 38.17862,
#   'lng': -76.9962,
#   'city': 'Colonial Beach',
#   'state': 'VA',
#   'tz': -5},
#  '03741': {'true_zip': '03741',
#   'country': 1,
#   'lat': 43.67188,
#   'lng': -72.01584,
#   'city': 'Canaan',
#   'state': 'NH',
#   'tz': -5},
#  '97006-1424': {'true_zip': '97006',
#   'country': 1,
#   'lat': 45.51704,
#   'lng': -122.85988,
#   'city': 'Beaverton',
#   'state': 'OR',
#   'tz': -8},
#  '99354': {'true_zip': '99354',
#   'country': 1,
#   'lat': 46.32566,
#   'lng': -119.3067,
#   'city': 'Richland',
#   'state': 'WA',
#   'tz': -8},
#  '59762': {'true_zip': '59762',
#   'country': 1,
#   'lat': 45.78639,
#   'lng': -113.15688,
#   'city': 'Wise River',
#   'state': 'MT',
#   'tz': -7},
#  '48458-9123': {'true_zip': '48458',
#   'country': 1,
#   'lat': 43.12225,
#   'lng': -83.68221,
#   'city': 'Mount Morris',
#   'state': 'MI',
#   'tz': -5},
#  '77705': {'true_zip': '77705',
#   'country': 1,
#   'lat': 29.9046,
#   'lng': -94.16146,
#   'city': 'Beaumont',
#   'state': 'TX',
#   'tz': -6},
#  '91334': {'true_zip': '91334',
#   'country': 1,
#   'lat': 34.2625,
#   'lng': -118.427,
#   'city': 'Pacoima',
#   'state': 'CA',
#   'tz': -8},
#  '08087': {'true_zip': '08087',
#   'country': 1,
#   'lat': 39.59283,
#   'lng': -74.37545,
#   'city': 'Tuckerton',
#   'state': 'NJ',
#   'tz': -5},
#  '77359': {'true_zip': '77359',
#   'country': 1,
#   'lat': 30.75385,
#   'lng': -95.29988,
#   'city': 'Oakhurst',
#   'state': 'TX',
#   'tz': -6},
#  '70451': {'true_zip': '70451',
#   'country': 1,
#   'lat': 30.5484,
#   'lng': -90.48091,
#   'city': 'Natalbany',
#   'state': 'LA',
#   'tz': -6},
#  '38134-4451': {'true_zip': '38134',
#   'country': 1,
#   'lat': 35.17696,
#   'lng': -89.85992,
#   'city': 'Memphis',
#   'state': 'TN',
#   'tz': -6},
#  '56025': {'true_zip': '56025',
#   'country': 1,
#   'lat': 43.75162,
#   'lng': -93.91077,
# ...
#   'lng': -75.97121,
#   'city': 'Harleigh',
#   'state': 'PA',
#   'tz': -5},
#  '27536': {'true_zip': '27536',
#   'country': 1,
#   'lat': 36.32669,
#   'lng': -78.40883,
#   'city': 'Henderson',
#   'state': 'NC',
#   'tz': -5},
#  '10035-3525': {'true_zip': '10035',
#   'country': 1,
#   'lat': 40.79551,
#   'lng': -73.92967,
#   'city': 'New York',
#   'state': 'NY',
#   'tz': -5},
#  '07933-1701': {'true_zip': '07933',
#   'country': 1,
#   'lat': 40.69196,
#   'lng': -74.46494,
#   'city': 'Gillette',
#   'state': 'NJ',
#   'tz': -5},
#  '74557': {'true_zip': '74557',
#   'country': 1,
#   'lat': 34.40176,
#   'lng': -95.69245,
#   'city': 'Moyers',
#   'state': 'OK',
#   'tz': -6},
#  '52586': {'true_zip': '52586',
#   'country': 1,
#   'lat': 41.34679,
#   'lng': -92.47041,
#   'city': 'Rose Hill',
#   'state': 'IA',
#   'tz': -6},
#  '30022-8613': {'true_zip': '30022',
#   'country': 1,
#   'lat': 34.03027,
#   'lng': -84.2472,
#   'city': 'Alpharetta',
#   'state': 'GA',
#   'tz': -5},
#  '213022': {'true_zip': '213022',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '23024': {'true_zip': '23024',
#   'country': 1,
#   'lat': 37.9254,
#   'lng': -77.77924,
#   'city': 'Bumpass',
#   'state': 'VA',
#   'tz': -5},
#  '215144': {'true_zip': '215144',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '86502': {'true_zip': '86502',
#   'country': 1,
#   'lat': 35.222,
#   'lng': -109.58173,
#   'city': 'Chambers',
#   'state': 'AZ',
#   'tz': -7},
#  '483064944': {'true_zip': '48306',
#   'country': 1,
#   'lat': 42.72323,
#   'lng': -83.14914,
#   'city': 'Rochester',
#   'state': 'MI',
#   'tz': -5},
#  '11222-5003': {'true_zip': '11222',
#   'country': 1,
#   'lat': 40.72858,
#   'lng': -73.94774,
#   'city': 'Brooklyn',
#   'state': 'NY',
#   'tz': -5},
#  '48913': {'true_zip': '48913',
#   'country': 1,
#   'lat': 42.7325,
#   'lng': -84.5555,
#   'city': 'Lansing',
#   'state': 'MI',
#   'tz': -5},
#  '24009': {'true_zip': '24009',
#   'country': 1,
#   'lat': 37.2742,
#   'lng': -79.9579,
#   'city': 'Roanoke',
#   'state': 'VA',
#   'tz': -5},
#  '84020-5164': {'true_zip': '84020',
#   'country': 1,
#   'lat': 40.50025,
#   'lng': -111.86742,
#   'city': 'Draper',
#   'state': 'UT',
#   'tz': -7},
#  '62684-9559': {'true_zip': '62684',
#   'country': 1,
#   'lat': 39.90928,
#   'lng': -89.58687,
#   'city': 'Sherman',
#   'state': 'IL',
#   'tz': -6},
#  '29417': {'true_zip': '29417',
#   'country': 1,
#   'lat': 32.8488,
#   'lng': -79.8577,
#   'city': 'Charleston',
#   'state': 'SC',
#   'tz': -5},
#  '24063': {'true_zip': '24063',
#   'country': 1,
#   'lat': 37.2296,
#   'lng': -80.4139,
#   'city': 'Blacksburg',
#   'state': 'VA',
#   'tz': -5},
#  '15370': {'true_zip': '15370',
#   'country': 1,
#   'lat': 39.87577,
#   'lng': -80.17563,
#   'city': 'Waynesburg',
#   'state': 'PA',
#   'tz': -5},
#  '40361-9112': {'true_zip': '40361',
#   'country': 1,
#   'lat': 38.20598,
#   'lng': -84.2273,
#   'city': 'Paris',
#   'state': 'KY',
#   'tz': -5},
#  '07646': {'true_zip': '07646',
#   'country': 1,
#   'lat': 40.93369,
#   'lng': -74.01957,
#   'city': 'New Milford',
#   'state': 'NJ',
#   'tz': -5},
#  '30157-7856': {'true_zip': '30157',
#   'country': 1,
#   'lat': 33.88586,
#   'lng': -84.87326,
#   'city': 'Dallas',
#   'state': 'GA',
#   'tz': -5},
#  '19152': {'true_zip': '19152',
#   'country': 1,
#   'lat': 40.0607,
#   'lng': -75.04673,
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'tz': -5},
#  '43522-9630': {'true_zip': '43522',
#   'country': 1,
#   'lat': 41.41914,
#   'lng': -83.84484,
#   'city': 'Grand Rapids',
#   'state': 'OH',
#   'tz': -5},
#  '107043728': {'true_zip': '10704',
#   'country': 1,
#   'lat': 40.91886,
#   'lng': -73.86176,
#   'city': 'Yonkers',
#   'state': 'NY',
#   'tz': -5},
#  '91335-4115': {'true_zip': '91335',
#   'country': 1,
#   'lat': 34.20105,
#   'lng': -118.54067,
#   'city': 'Reseda',
#   'state': 'CA',
#   'tz': -8},
#  '98502': {'true_zip': '98502',
#   'country': 1,
#   'lat': 47.09052,
#   'lng': -123.01239,
#   'city': 'Olympia',
#   'state': 'WA',
#   'tz': -8},
#  '32403-1012': {'true_zip': '32403',
#   'country': 1,
#   'lat': 30.05338,
#   'lng': -85.5568,
#   'city': 'Panama City',
#   'state': 'FL',
#   'tz': -6},
#  '71107-5209': {'true_zip': '71107',
#   'country': 1,
#   'lat': 32.59665,
#   'lng': -93.85878,
#   'city': 'Shreveport',
#   'state': 'LA',
#   'tz': -6},
#  '19442': {'true_zip': '19442',
#   'country': 1,
#   'lat': 40.12953,
#   'lng': -75.58314,
#   'city': 'Kimberton',
#   'state': 'PA',
#   'tz': -5},
#  '45301': {'true_zip': '45301',
#   'country': 1,
#   'lat': 39.71146,
#   'lng': -84.02204,
#   'city': 'Alpha',
#   'state': 'OH',
#   'tz': -5},
#  '27603-8980': {'true_zip': '27603',
#   'country': 1,
#   'lat': 35.66355,
#   'lng': -78.66172,
#   'city': 'Raleigh',
#   'state': 'NC',
#   'tz': -5},
#  '90061-2738': {'true_zip': '90061',
#   'country': 1,
#   'lat': 33.92045,
#   'lng': -118.27403,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'tz': -8},
#  '89441': {'true_zip': '89441',
#   'country': 1,
#   'lat': 39.67635,
#   'lng': -119.6758,
#   'city': 'Sparks',
#   'state': 'NV',
#   'tz': -8},
#  '76166': {'true_zip': '76166',
#   'country': 1,
#   'lat': 32.7539,
#   'lng': -97.3362,
#   'city': 'Fort Worth',
#   'state': 'TX',
#   'tz': -6},
#  '91710': {'true_zip': '91710',
#   'country': 1,
#   'lat': 34.00447,
#   'lng': -117.68468,
#   'city': 'Chino',
#   'state': 'CA',
#   'tz': -8},
#  '72007': {'true_zip': '72007',
#   'country': 1,
#   'lat': 35.00244,
#   'lng': -91.98189,
#   'city': 'Austin',
#   'state': 'AR',
#   'tz': -6},
#  '54452-1409': {'true_zip': '54452',
#   'country': 1,
#   'lat': 45.20989,
#   'lng': -89.76838,
#   'city': 'Merrill',
#   'state': 'WI',
#   'tz': -6},
#  '41631': {'true_zip': '41631',
#   'country': 1,
#   'lat': 37.47297,
#   'lng': -82.65525,
#   'city': 'Grethel',
#   'state': 'KY',
#   'tz': -5},
#  '19096': {'true_zip': '19096',
#   'country': 1,
#   'lat': 39.99786,
#   'lng': -75.27419,
#   'city': 'Wynnewood',
#   'state': 'PA',
#   'tz': -5},
#  '95407-2590': {'true_zip': '95407',
#   'country': 1,
#   'lat': 38.39452,
#   'lng': -122.74435,
#   'city': 'Santa Rosa',
#   'state': 'CA',
#   'tz': -8},
#  '17035': {'true_zip': '17035',
#   'country': 1,
#   'lat': 40.41635,
#   'lng': -77.57482,
#   'city': 'Honey Grove',
#   'state': 'PA',
#   'tz': -5},
#  '78164': {'true_zip': '78164',
#   'country': 1,
#   'lat': 28.98216,
#   'lng': -97.52254,
#   'city': 'Yorktown',
#   'state': 'TX',
#   'tz': -6},
#  '34293-7215': {'true_zip': '34293',
#   'country': 1,
#   'lat': 27.02802,
#   'lng': -82.33552,
#   'city': 'Venice',
#   'state': 'FL',
#   'tz': -5},
#  '37178': {'true_zip': '37178',
#   'country': 1,
#   'lat': 36.32318,
#   'lng': -87.78422,
#   'city': 'Tennessee Ridge',
#   'state': 'TN',
#   'tz': -6},
#  '91043-0459': {'true_zip': '91043',
#   'country': 1,
#   'lat': 34.2522,
#   'lng': -118.2884,
#   'city': 'Tujunga',
#   'state': 'CA',
#   'tz': -8},
#  '56553': {'true_zip': '56553',
#   'country': 1,
#   'lat': 46.42885,
#   'lng': -96.61825,
#   'city': 'Kent',
#   'state': 'MN',
#   'tz': -6},
#  '97834': {'true_zip': '97834',
#   'country': 1,
#   'lat': 44.96864,
#   'lng': -117.18919,
#   'city': 'Halfway',
#   'state': 'OR',
#   'tz': -8},
#  '92705-3862': {'true_zip': '92705',
#   'country': 1,
#   'lat': 33.75566,
#   'lng': -117.81639,
#   'city': 'Santa Ana',
#   'state': 'CA',
#   'tz': -8},
#  '54622': {'true_zip': '54622',
#   'country': 1,
#   'lat': 44.26719,
#   'lng': -91.77157,
#   'city': 'Cochrane',
#   'state': 'WI',
#   'tz': -6},
#  '89009-2582': {'true_zip': '89009',
#   'country': 1,
#   'lat': 35.9279,
#   'lng': -114.9721,
#   'city': 'Henderson',
#   'state': 'NV',
#   'tz': -8},
#  '33168': {'true_zip': '33168',
#   'country': 1,
#   'lat': 25.89293,
#   'lng': -80.20929,
#   'city': 'Miami',
#   'state': 'FL',
#   'tz': -5},
#  '04210': {'true_zip': '04210',
#   'country': 1,
#   'lat': 44.0849,
#   'lng': -70.24922,
#   'city': 'Auburn',
#   'state': 'ME',
#   'tz': -5},
#  '76379': {'true_zip': '76379',
#   'country': 1,
#   'lat': 33.67016,
#   'lng': -98.47541,
#   'city': 'Scotland',
#   'state': 'TX',
#   'tz': -6},
#  '45437': {'true_zip': '45437',
#   'country': 1,
#   'lat': 39.7505,
#   'lng': -84.2686,
#   'city': 'Dayton',
#   'state': 'OH',
#   'tz': -5},
#  '35902': {'true_zip': '35902',
#   'country': 1,
#   'lat': 34.0143,
#   'lng': -86.0066,
#   'city': 'Gadsden',
#   'state': 'AL',
#   'tz': -6},
#  '97027-2562': {'true_zip': '97027',
#   'country': 1,
#   'lat': 45.38692,
#   'lng': -122.59285,
#   'city': 'Gladstone',
#   'state': 'OR',
#   'tz': -8},
#  '104631545': {'true_zip': '10463',
#   'country': 1,
#   'lat': 40.88077,
#   'lng': -73.90662,
#   'city': 'Bronx',
#   'state': 'NY',
#   'tz': -5},
#  '98229-7954': {'true_zip': '98229',
#   'country': 1,
#   'lat': 48.6955,
#   'lng': -122.41046,
#   'city': 'Bellingham',
#   'state': 'WA',
#   'tz': -8},
#  '85751': {'true_zip': '85751',
#   'country': 1,
#   'lat': 32.2217,
#   'lng': -110.9265,
#   'city': 'Tucson',
#   'state': 'AZ',
#   'tz': -7},
#  '10927': {'true_zip': '10927',
#   'country': 1,
#   'lat': 41.19257,
#   'lng': -73.96708,
#   'city': 'Haverstraw',
#   'state': 'NY',
#   'tz': -5},
#  '77430': {'true_zip': '77430',
#   'country': 1,
#   'lat': 29.26718,
#   'lng': -95.65366,
#   'city': 'Damon',
#   'state': 'TX',
#   'tz': -6},
#  '16105-5945': {'true_zip': '16105',
#   'country': 1,
#   'lat': 41.05351,
#   'lng': -80.33815,
#   'city': 'New Castle',
#   'state': 'PA',
#   'tz': -5},
#  '97239': {'true_zip': '97239',
#   'country': 1,
#   'lat': 45.48842,
#   'lng': -122.69061,
#   'city': 'Portland',
#   'state': 'OR',
#   'tz': -8},
#  '98834': {'true_zip': '98834',
#   'country': 1,
#   'lat': 48.11708,
#   'lng': -120.08911,
#   'city': 'Methow',
#   'state': 'WA',
#   'tz': -8},
#  '15447': {'true_zip': '15447',
#   'country': 1,
#   'lat': 39.94384,
#   'lng': -79.93692,
#   'city': 'Isabella',
#   'state': 'PA',
#   'tz': -5},
#  '51515': {'true_zip': '51515',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '189401107': {'true_zip': '18940',
#   'country': 1,
#   'lat': 40.2632,
#   'lng': -74.94751,
#   'city': 'Newtown',
#   'state': 'PA',
#   'tz': -5},
#  '32061': {'true_zip': '32061',
#   'country': 1,
#   'lat': 30.09757,
#   'lng': -82.51031,
#   'city': 'Lulu',
#   'state': 'FL',
#   'tz': -5},
#  '56024': {'true_zip': '56024',
#   'country': 1,
#   'lat': 44.15134,
#   'lng': -93.84783,
#   'city': 'Eagle Lake',
#   'state': 'MN',
#   'tz': -6},
#  '54153': {'true_zip': '54153',
#   'country': 1,
#   'lat': 44.90181,
#   'lng': -87.92149,
#   'city': 'Oconto',
#   'state': 'WI',
#   'tz': -6},
#  '58673': {'true_zip': '58673',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '78216-2065': {'true_zip': '78216',
#   'country': 1,
#   'lat': 29.53648,
#   'lng': -98.48922,
#   'city': 'San Antonio',
#   'state': 'TX',
#   'tz': -6},
#  '19446-4707': {'true_zip': '19446',
#   'country': 1,
#   'lat': 40.23199,
#   'lng': -75.30376,
#   'city': 'Lansdale',
#   'state': 'PA',
#   'tz': -5},
#  '33181-1656': {'true_zip': '33181',
#   'country': 1,
#   'lat': 25.89873,
#   'lng': -80.1509,
#   'city': 'Miami',
#   'state': 'FL',
#   'tz': -5},
#  '03047-0067': {'true_zip': '03047',
#   'country': 1,
#   'lat': 42.94007,
#   'lng': -71.87021,
#   'city': 'Greenfield',
#   'state': 'NH',
#   'tz': -5},
#  '30041-8094': {'true_zip': '30041',
#   'country': 1,
#   'lat': 34.20039,
#   'lng': -84.09418,
#   'city': 'Cumming',
#   'state': 'GA',
#   'tz': -5},
#  '79706-2553': {'true_zip': '79706',
#   'country': 1,
#   'lat': 31.84553,
#   'lng': -102.00236,
#   'city': 'Midland',
#   'state': 'TX',
#   'tz': -6},
#  '63077-4654': {'true_zip': '63077',
#   'country': 1,
#   'lat': 38.32711,
#   'lng': -90.98631,
#   'city': 'Saint Clair',
#   'state': 'MO',
#   'tz': -6},
#  '48366': {'true_zip': '48366',
#   'country': 1,
#   'lat': 42.8214,
#   'lng': -83.1502,
#   'city': 'Lakeville',
#   'state': 'MI',
#   'tz': -5},
#  '47441': {'true_zip': '47441',
#   'country': 1,
#   'lat': 39.04328,
#   'lng': -87.16595,
#   'city': 'Linton',
#   'state': 'IN',
#   'tz': -5},
#  '07071-3554': {'true_zip': '07071',
#   'country': 1,
#   'lat': 40.79635,
#   'lng': -74.10991,
#   'city': 'Lyndhurst',
#   'state': 'NJ',
#   'tz': -5},
#  '63830-0484': {'true_zip': '63830',
#   'country': 1,
#   'lat': 36.13007,
#   'lng': -89.69068,
#   'city': 'Caruthersville',
#   'state': 'MO',
#   'tz': -6},
#  '88015': {'true_zip': '88015',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '912051430': {'true_zip': '91205',
#   'country': 1,
#   'lat': 34.13666,
#   'lng': -118.24332,
#   'city': 'Glendale',
#   'state': 'CA',
#   'tz': -8},
#  '32732': {'true_zip': '32732',
#   'country': 1,
#   'lat': 28.74551,
#   'lng': -81.10597,
#   'city': 'Geneva',
#   'state': 'FL',
#   'tz': -5},
#  '46234': {'true_zip': '46234',
#   'country': 1,
#   'lat': 39.81252,
#   'lng': -86.32566,
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'tz': -5},
#  '12092': {'true_zip': '12092',
#   'country': 1,
#   'lat': 42.70126,
#   'lng': -74.37659,
#   'city': 'Howes Cave',
#   'state': 'NY',
#   'tz': -5},
#  '32937-2450': {'true_zip': '32937',
#   'country': 1,
#   'lat': 28.17832,
#   'lng': -80.60427,
#   'city': 'Satellite Beach',
#   'state': 'FL',
#   'tz': -5},
#  '55328-4709': {'true_zip': '55328',
#   'country': 1,
#   'lat': 45.03575,
#   'lng': -93.81318,
#   'city': 'Delano',
#   'state': 'MN',
#   'tz': -6},
#  '891085049': {'true_zip': '89108',
#   'country': 1,
#   'lat': 36.20531,
#   'lng': -115.22367,
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'tz': -8},
#  '33328-3530': {'true_zip': '33328',
#   'country': 1,
#   'lat': 26.06714,
#   'lng': -80.27223,
#   'city': 'Fort Lauderdale',
#   'state': 'FL',
#   'tz': -5},
#  '120 54': {'true_zip': '120 54',
#   'country': 2,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '44654': {'true_zip': '44654',
#   'country': 1,
#   'lat': 40.53909,
#   'lng': -81.87079,
#   'city': 'Millersburg',
#   'state': 'OH',
#   'tz': -5},
#  '27264': {'true_zip': '27264',
#   'country': 1,
#   'lat': 36.0807,
#   'lng': -80.0244,
#   'city': 'High Point',
#   'state': 'NC',
#   'tz': -5},
#  '226315': {'true_zip': '226315',
#   'country': 8,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  '82801-6362': {'true_zip': '82801',
#   'country': 1,
#   'lat': 44.8445,
#   'lng': -106.83968,
#   'city': 'Sheridan',
#   'state': 'WY',
#   'tz': -7},
#  '61752': {'true_zip': '61752',
#   'country': 1,
#   'lat': 40.33908,
#   'lng': -88.7548,
#   'city': 'Le Roy',
#   'state': 'IL',
#   'tz': -6},
#  '85375': {'true_zip': '85375',
#   'country': 1,
#   'lat': 33.68563,
#   'lng': -112.36604,
#   'city': 'Sun City West',
#   'state': 'AZ',
#   'tz': -7},
#  '25123': {'true_zip': '25123',
#   'country': 1,
#   'lat': 38.73473,
#   'lng': -81.90386,
#   'city': 'Leon',
#   'state': 'WV',
#   'tz': -5},
#  '68107-3706': {'true_zip': '68107',
#   'country': 1,
#   'lat': 41.20841,
#   'lng': -95.95167,
#   'city': 'Omaha',
#   'state': 'NE',
#   'tz': -6},
#  '28111-3587': {'true_zip': '28111',
#   'country': 1,
#   'lat': 35.0112,
#   'lng': -80.5587,
#   'city': 'Monroe',
#   'state': 'NC',
#   'tz': -5},
#  '45414': {'true_zip': '45414',
#   'country': 1,
#   'lat': 39.84254,
#   'lng': -84.21243,
#   'city': 'Dayton',
#   'state': 'OH',
#   'tz': -5},
#  '43909': {'true_zip': '43909',
#   'country': 1,
#   'lat': 40.0701,
#   'lng': -80.8176,
#   'city': 'Blaine',
#   'state': 'OH',
#   'tz': -5},
#  '49915': {'true_zip': '49915',
#   'country': 1,
#   'lat': 46.06511,
#   'lng': -88.62197,
#   'city': 'Caspian',
#   'state': 'MI',
#   'tz': -6},
#  '17862': {'true_zip': '17862',
#   'country': 1,
#   'lat': 40.86052,
#   'lng': -77.05692,
#   'city': 'Penns Creek',
#   'state': 'PA',
#   'tz': -5},
#  '19564': {'true_zip': '19564',
#   'country': 1,
#   'lat': 40.52158,
#   'lng': -75.87444,
#   'city': 'Virginville',
#   'state': 'PA',
#   'tz': -5},
#  '48439-5106': {'true_zip': '48439',
#   'country': 1,
#   'lat': 42.91681,
#   'lng': -83.62911,
#   'city': 'Grand Blanc',
#   'state': 'MI',
#   'tz': -5},
#  '29680-7540': {'true_zip': '29680',
#   'country': 1,
#   'lat': 34.68859,
#   'lng': -82.29155,
#   'city': 'Simpsonville',
#   'state': 'SC',
#   'tz': -5},
#  '33328-3817': {'true_zip': '33328',
#   'country': 1,
#   'lat': 26.06714,
#   'lng': -80.27223,
#   'city': 'Fort Lauderdale',
#   'state': 'FL',
#   'tz': -5},
#  '54986-0194': {'true_zip': '54986',
#   'country': 1,
#   'lat': 44.12078,
#   'lng': -88.7475,
#   'city': 'Winneconne',
#   'state': 'WI',
#   'tz': -6},
#  '96921-6964': {'true_zip': '96921',
#   'country': 1,
#   'lat': 13.45902,
#   'lng': 144.79397,
#   'city': 'Barrigada',
#   'state': 'GU',
#   'tz': 10},
#  '38410': {'true_zip': '38410',
#   'country': 7,
#   'lat': False,
#   'lng': False,
#   'city': False,
#   'state': False,
#   'tz': False},
#  ...}

# %%
unseened_data = []
for k, v in cleaned_zipcode.items():
    if v['country'] == 7:
        unseened_data.append(k)

# %%
len(unseened_data)
# Out:
# 2444

# %%
left_data = []
for k, v in cleaned_zipcode.items():
    if v['country'] == 7:
        new_zip = v['true_zip'][:3] + '01'
        if new_zip in ref_dict:
            cleaned_zipcode[k] = {
                'true_zip': new_zip,
                'country': 1,
                'lat': ref_dict[new_zip]['lat'],
                'lng': ref_dict[new_zip]['lng'],
                'city': ref_dict[new_zip]['city'],
                'state': ref_dict[new_zip]['state'],
                'tz': tz_dict[ref_dict[nzc]['tz']]
            }
        else:
            left_data.append(k)

# %%
len(left_data)
# Out:
# 796

# %%
unseened_data2 = []
all_tz = set()
for k, v in cleaned_zipcode.items():
    if v['country'] == 1:
        if not v['tz'] or v['tz'] is None: 
            unseened_data2.append(k)
        else:
            all_tz.add(v['tz'])

# %%
cleaned_zipcode['34236']
# Out:
# {'true_zip': '34236',
#  'country': 1,
#  'lat': 27.32626,
#  'lng': -82.5572,
#  'city': 'Sarasota',
#  'state': 'FL',
#  'tz': -5}

# %%
len(unseened_data2)
# Out:
# 85

# %%
all_tz
# Out:
# {-11, -10, -9, -8, -7, -6, -5, -4, 1, 3, 5, 8, 9, 9.5, 10}

# %%
json.dump(cleaned_zipcode, open('data/zipcode_dict.json', 'w'))

# %%
tz_type = set()
for k, v in cleaned_zipcode.items():
    tz_type.add(v['tz'])

# %%
tz_type
# Out:
# {-11, -10, -9, -8, -7, -6, -5, -4, False, 1, 3, 5, 8, 9, 9.5, 10}
